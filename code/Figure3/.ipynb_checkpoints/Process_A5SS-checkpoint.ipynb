# %% [markdown]
# ## Load variants and PSIs

# %%
projectDIR = "../../data/gtex/"

# %%
import joblib
df = joblib.load(projectDIR+"A5SS_sample_variants.pkl")

# %%
df.head(2)
# Out:
#                                            event_name         VARIANT  \
# 12  chr7:99810756:99810576|99810646:-@chr7:9980901...  7_99810643_T_G
# 14  chr7:99810756:99810646|99810670:-@chr7:9980901...  7_99810643_T_G
#
#                                                  HOMO  \
# 12  [7, 10, 14, 20, 27, 32, 33, 37, 40, 42, 50, 54...
# 14  [7, 10, 14, 20, 27, 32, 33, 37, 40, 42, 50, 54...
#
#                                                HETERO  \
# 12  [2, 6, 9, 13, 18, 19, 22, 26, 30, 31, 34, 39, ...
# 14  [2, 6, 9, 13, 18, 19, 22, 26, 30, 31, 34, 39, ...
#
#                                                    WT  \
# 12  [0, 11, 21, 23, 56, 57, 58, 64, 70, 97, 115, 1...
# 14  [0, 11, 21, 23, 56, 57, 58, 64, 70, 97, 115, 1...
#
#                                              HOMO_PSI  \
# 12  [0.26, 0.49, 0.31, 0.21, 0.62, 0.59, 0.21, nan...
# 14  [0.13, 0.04, 0.12, 0.06, 0.03, 0.1, 0.03, nan,...
#
#                                            HETERO_PSI  \
# 12  [0.54, 0.32, 0.41, 0.48, 0.39, 0.52, 0.06, 0.2...
# 14  [0.26, 0.15, 0.22, 0.1, 0.12, 0.12, 0.07, 0.13...
#
#                                                WT_PSI  HOMO_COUNT  \
# 12  [0.56, 0.29, 0.39, 0.28, 0.2, 0.34, 0.09, 0.08...         310
# 14  [0.14, 0.39, 0.35, 0.26, 0.28, 0.2, 0.23, 0.3,...         310
#
#     HETERO_COUNT     ...       SD_DIST isSNP SD1_MUT SD2_MUT SD_MUT  EXON_MUT  \
# 12           336     ...            70  True    True   False   True     False
# 14           336     ...            24  True   False    True   True     False
#
#     INTRON_MUT  HOMO_MEAN   WT_MEAN  HETERO_MEAN
# 12       False   0.320097  0.197791     0.242292
# 14       False   0.068097  0.229302     0.144643
#
# [2 rows x 27 columns]

# %% [markdown]
# ## Split into variant-exon pair format for the two alternative exons

# %%
def get_alt_exon(event_name, SD1=True):
    ''' Give coordinates of the two alternative exons
    '''
    strand = event_name[-1]
    event_split = event_name.split(":")
    chrom = event_split[0]
    if strand == "+":
        start = event_split[1]
        if SD1:
            end = event_split[2].split('|')[0]
        else:
            end = event_split[2].split('|')[1]
    else:
        if SD1:
            start = event_split[2].split('|')[1]
        else:
            start = event_split[2].split('|')[0]
        end = event_split[1]
    return chrom, start, end, strand

# %%
from copy import deepcopy
df_SD1 = deepcopy(df)
df_SD2 = deepcopy(df)

# %%
df_SD1['seqnames'], df_SD1['exon_start'], df_SD1['exon_end'], df_SD1['strand'] = zip(*df.event_name.apply(get_alt_exon))

# %%
df_SD1 = df_SD1[['event_name', 'VARIANT', 'seqnames', 'exon_start', 'exon_end', 'strand', 'variant_position', 'REF', 'ALT', 'ID']]

# %%
df_SD1.to_csv(projectDIR + 'A5SS_SD1_variant.csv')

# %%
df_SD2['seqnames'], df_SD2['exon_start'], df_SD2['exon_end'], df_SD2['strand'] = zip(*df.event_name.apply(lambda x: get_alt_exon(x, SD1=False)))

# %%
df_SD2 = df_SD2[['event_name', 'VARIANT', 'seqnames', 'exon_start', 'exon_end', 'strand', 'variant_position', 'REF', 'ALT', 'ID']]

# %%
df_SD2.to_csv(projectDIR+'A5SS_SD2_variant.csv')
